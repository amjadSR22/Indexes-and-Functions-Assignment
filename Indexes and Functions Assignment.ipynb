# %%
import pymongo
import certifi
ca = certifi.where()

# %%
client = pymongo.MongoClient("mongodb://_:1ViXanRRqj5Gt6Iy3x34KuDeDjhWuQJsRu4zSz9rLL0xuTXMbspCVyBBnpa8AsO1@global.aws.realm.mongodb.com:27020/?authMechanism=PLAIN&authSource=%24external&ssl=true&appName=application-r-ikqgd:amjad_2211:api-key",tlsCAFile=ca)
client
# Out:
# MongoClient(host=['global.aws.realm.mongodb.com:27020'], document_class=dict, tz_aware=False, connect=True, authmechanism='PLAIN', authsource='$external', appname='application-r-ikqgd:amjad_2211:api-key', tlscafile='C:\\Users\\Amjad\\anaconda3\\lib\\site-packages\\certifi\\cacert.pem', tls=True)

# %%
#get database 
db = client["football"]
db
# Out:
# Database(MongoClient(host=['global.aws.realm.mongodb.com:27020'], document_class=dict, tz_aware=False, connect=True, authmechanism='PLAIN', authsource='$external', appname='application-r-ikqgd:amjad_2211:api-key', tlscafile='C:\\Users\\Amjad\\anaconda3\\lib\\site-packages\\certifi\\cacert.pem', tls=True), 'football')

# %%
# get collection 
collection = db.get_collection("foot_ball")
collection
# Out:
# Collection(Database(MongoClient(host=['global.aws.realm.mongodb.com:27020'], document_class=dict, tz_aware=False, connect=True, authmechanism='PLAIN', authsource='$external', appname='application-r-ikqgd:amjad_2211:api-key', tlscafile='C:\\Users\\Amjad\\anaconda3\\lib\\site-packages\\certifi\\cacert.pem', tls=True), 'football'), 'foot_ball')

# %%
# get function 
my_choose= db.command("callFunction", "my_choose")
my_choose
# Out:
# {'ok': 1,
#  'response': [{'_id': ObjectId('63459e86c4c40c0c181c241d'),
#    'height': 192,
#    'weight': 80,
#    'age': 31,
#    'isManOfTheMatch': True,
#    'isActive': True,
#    'teamRegionName': 'Spain',
#    'apps': 36,
#    'subOn': 5,
#    'manOfTheMatch': 10,
#    'goal': 11,
#    'assistTotal': 2,
#    'shotsPerGame': Decimal128('2.416666666666666'),
#    'aerialWonPerGame': Decimal128('8.666666666666666'),
#    'name': 'Joselu',
#    'firstName': 'Jose Luis',
#    'lastName': 'Mato Sanmartín',
#    'playerId': 74603,
#    'positionText': 'Forward',
#    'teamId': 60,
#    'teamName': 'Deportivo Alaves',
#    'seasonName': '2019/2020',
#    'isOpta': True,
#    'tournamentRegionName': 'Spain',
#    'tournamentName': 'LaLiga',
#    'rating': Decimal128('7.215555555555554'),
#    'minsPlayed': 2786,
#    'yellowCard': 6,
#    'redCard': 0,
#    'passSuccess': Decimal128('52.01654601861427'),
#    'ranking': 9,
#    'originCountry': 'Spain'}]}

# %%
age= db.command("callFunction", "players_age")
age
# Out:
# {'ok': 1,
#  'response': [{'_id': ObjectId('63459e86c4c40c0c181c247e'),
#    'height': 173,
#    'weight': 67,
#    'age': 19,
#    'isManOfTheMatch': True,
#    'isActive': True,
#    'teamRegionName': 'Spain',
#    'apps': 35,
#    'subOn': 12,
#    'manOfTheMatch': 1,
#    'goal': 4,
#    'assistTotal': 4,
#    'shotsPerGame': Decimal128('1.5714285714285712'),
#    'aerialWonPerGame': Decimal128('0.342857142857142'),
#    'name': 'Takefusa Kubo',
#    'firstName': 'Takefusa',
#    'lastName': 'Kubo',
#    'playerId': 377285,
#    'positionText': 'Midfielder',
#    'teamId': 51,
#    'teamName': 'Mallorca',
#    'seasonName': '2019/2020',
#    'isOpta': True,
#    'tournamentRegionName': 'Spain',
#    'tournamentName': 'LaLiga',
#    'rating': Decimal128('6.746571428571428'),
#    'minsPlayed': 2309,
#    'yellowCard': 4,
#    'redCard': 0,
#    'passSuccess': Decimal128('75.25773195876289'),
#    'ranking': 106,
#    'originCountry': 'Japan'},
# ...

# %%
r_p= db.command("callFunction", "returnsplayers")
r_p
# Out:
# {'ok': 1,
#  'response': [{'name': 'Lionel Messi'},
#   {'name': 'Casemiro'},
#   {'name': 'Karim Benzema'},
#   {'name': 'Luis Suárez'},
#   {'name': 'Mikel Merino'},
#   {'name': 'Gerard Moreno'},
#   {'name': 'Nabil Fekir'},
#   {'name': 'Saúl Ñíguez'},
#   {'name': 'Joselu'},
#   {'name': 'Lucas Ocampos'},
#   {'name': 'Raúl García'},
#   {'name': 'Toni Kroos'},
#   {'name': 'Daniel Carvajal'},
#   {'name': 'Santi Cazorla'},
#   {'name': 'Chimy Avila'},
#   {'name': 'Rafinha'},
#   {'name': 'Martin Ødegaard'},
#   {'name': 'Éver Banega'},
#   {'name': 'Sergio Reguilón'},
#   {'name': 'Thomas Partey'},
#   {'name': 'Sergio Ramos'},
#   {'name': 'Sergio Busquets'},
#   {'name': 'André-Frank Zambo Anguissa'},
#   {'name': 'Mikel Oyarzabal'},
#   {'name': 'Gerard Piqué'},
#   {'name': 'Koke'},
#   {'name': 'Daniel Parejo'},
#   {'name': 'Luka Modric'},
#   {'name': 'Ferland Mendy'},
#   {'name': 'José Campaña'},
#   {'name': 'Yeray Álvarez'},
#   {'name': 'Kieran Trippier'},
# ...

# %%
t_n= db.command("callFunction", "teamName")
t_n
# Out:
# {'ok': 1,
#  'response': [{'_id': {'teamName': 'Real Betis'}, 'round_2': 3.14},
#   {'_id': {'teamName': 'Eibar'}, 'round_2': 2.4},
#   {'_id': {'teamName': 'Valencia'}, 'round_2': 2.5},
#   {'_id': {'teamName': 'Real Sociedad'}, 'round_2': 3.79},
#   {'_id': {'teamName': 'Osasuna'}, 'round_2': 2.25},
#   {'_id': {'teamName': 'Mallorca'}, 'round_2': 2.44},
#   {'_id': {'teamName': 'Granada'}, 'round_2': 2.93},
#   {'_id': {'teamName': 'Villarreal'}, 'round_2': 3.4},
#   {'_id': {'teamName': 'Sevilla'}, 'round_2': 3.07},
#   {'_id': {'teamName': 'Real Madrid'}, 'round_2': 4.23},
#   {'_id': {'teamName': 'Real Valladolid'}, 'round_2': 1.88},
#   {'_id': {'teamName': 'Deportivo Alaves'}, 'round_2': 2.13},
#   {'_id': {'teamName': 'Celta Vigo'}, 'round_2': 2.21},
#   {'_id': {'teamName': 'Levante'}, 'round_2': 2.59},
#   {'_id': {'teamName': 'Barcelona'}, 'round_2': 5.33},
#   {'_id': {'teamName': 'Athletic Bilbao'}, 'round_2': 2.64},
# ...

# %%
score= db.command("callFunction", "score", arguments=[5])
score
# Out:
# {'ok': 1,
#  'response': [{'goal': 25, 'name': 'Lionel Messi', 'teamName': 'Barcelona'},
#   {'goal': 21, 'name': 'Karim Benzema', 'teamName': 'Real Madrid'},
#   {'goal': 16, 'name': 'Luis Suárez', 'teamName': 'Barcelona'},
#   {'goal': 5, 'name': 'Mikel Merino', 'teamName': 'Real Sociedad'},
#   {'goal': 18, 'name': 'Gerard Moreno', 'teamName': 'Villarreal'},
#   {'goal': 7, 'name': 'Nabil Fekir', 'teamName': 'Real Betis'},
#   {'goal': 6, 'name': 'Saúl Ñíguez', 'teamName': 'Atletico'},
#   {'goal': 11, 'name': 'Joselu', 'teamName': 'Deportivo Alaves'},
#   {'goal': 14, 'name': 'Lucas Ocampos', 'teamName': 'Sevilla'},
#   {'goal': 15, 'name': 'Raúl García', 'teamName': 'Athletic Bilbao'},
#   {'goal': 11, 'name': 'Santi Cazorla', 'teamName': 'Villarreal'},
#   {'goal': 9, 'name': 'Chimy Avila', 'teamName': 'Osasuna'},
#   {'goal': 11, 'name': 'Sergio Ramos', 'teamName': 'Real Madrid'},
#   {'goal': 10, 'name': 'Mikel Oyarzabal', 'teamName': 'Real Sociedad'},
# ...

# %%
assists= db.command("callFunction", "assists") # ask about this function 
assists
# Out:
# {'ok': 1,
#  'response': [{'_id': {'teamName': 'Real Betis'}, 'round_2': None},
#   {'_id': {'teamName': 'Eibar'}, 'round_2': None},
#   {'_id': {'teamName': 'Valencia'}, 'round_2': None},
#   {'_id': {'teamName': 'Real Sociedad'}, 'round_2': None},
#   {'_id': {'teamName': 'Osasuna'}, 'round_2': None},
#   {'_id': {'teamName': 'Mallorca'}, 'round_2': None},
#   {'_id': {'teamName': 'Granada'}, 'round_2': None},
#   {'_id': {'teamName': 'Villarreal'}, 'round_2': None},
#   {'_id': {'teamName': 'Sevilla'}, 'round_2': None},
#   {'_id': {'teamName': 'Real Madrid'}, 'round_2': None},
#   {'_id': {'teamName': 'Real Valladolid'}, 'round_2': None},
#   {'_id': {'teamName': 'Deportivo Alaves'}, 'round_2': None},
#   {'_id': {'teamName': 'Celta Vigo'}, 'round_2': None},
#   {'_id': {'teamName': 'Levante'}, 'round_2': None},
#   {'_id': {'teamName': 'Barcelona'}, 'round_2': None},
#   {'_id': {'teamName': 'Athletic Bilbao'}, 'round_2': None},
# ...
